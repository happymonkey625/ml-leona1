# %% [markdown]
# <a href="https://colab.research.google.com/github/happymonkey625/ml-leona1/blob/main/HuggingFace_image_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.0 MB/s eta 0:00:00

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from transformers import pipeline

# %%
# !wget -o img2text.jpg 'https://photos.google.com/photo/AF1QipOnLz8vJbbJfIgyQufX5-HTZZTExQljvYjdJ4Sb'

# %%
from IPython.display import Image

# %%
Image(filename='vision_AI.jpg')

# %%
captioner = pipeline("image-to-text",model="Salesforce/blip-image-captioning-base")

# %%
captioner('vision_AI.jpg')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'a woman and a man standing next to each other '}]

# %% [markdown]
# # New section
